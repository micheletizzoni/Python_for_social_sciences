# %% [markdown]
# <center>
# <hr>
# <h1>Python Crash Course</h1>
# <h3>PhD Programme in Sociology and Social Research</h3>
# <h3>Michele Tizzoni</h3>
# <h2>Notebook 2 - Data analysis with Pandas and visualization</h2>
# <hr>
# </center>

# %% [markdown]
# The aim of this second lesson is to:
#  - guide you through most common steps in data cleaning and processing (with a df-centric approach)
#  - show you how to conduct exploratory data analysis in Python
#  - cover essential visualization

# %% [markdown]
# # Pandas

# %% [markdown]
# **Pandas** is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.
#
# https://pandas.pydata.org/

# %% [markdown]
# DataFrames are a 2-dimensional labeled data structures at the core of the Pandas library → the Excel spreadsheet alter-ego.
#
#
#
# Basically a table with columns and rows: **the lifetime partner of our research struggles and joys**.

# %%
import pandas as pd

# %% [markdown]
# Let's create a dataframe. There are two ways of doing that.
#
# ### Case 1
# **We create a dataframe from a dictionary.** This is useful in 0.0001\% of cases but it's a good starting point to learn some basics.

# %%
sample = { "course" : ['math', 'biology', 'cs'], "grade": [10, 8, 4] }

# %%
df = pd.DataFrame(sample)

# %%
df
# Out:
#     course  grade
# 0     math     10
# 1  biology      8
# 2       cs      4

# %%
df.dtypes
# Out:
# course    object
# grade      int64
# dtype: object

# %% [markdown]
# Let's add a new column

# %%
df['total students'] = [20, 21, 14]

# %%
df
# Out:
#     course  grade  total students
# 0     math     10              20
# 1  biology      8              21
# 2       cs      4              14

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['course', 'grade', 'total students'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([['math', 10, 20],
#        ['biology', 8, 21],
#        ['cs', 4, 14]], dtype=object)

# %% [markdown]
# ### Selecting rows and columns

# %%
df.loc[1]
# Out:
# course            biology
# grade                   8
# total students         21
# Name: 1, dtype: object

# %%
df.loc[1,'course']
# Out:
# 'biology'

# %%
df.loc[:2]
# Out:
#     course  grade  total students
# 0     math     10              20
# 1  biology      8              21
# 2       cs      4              14

# %%
df.loc[:2,'grade']
# Out:
# 0    10
# 1     8
# 2     4
# Name: grade, dtype: int64

# %% [markdown]
# ### Extending a dataframe

# %%
df1 = pd.DataFrame({"course" : ['social science'], "grade": [10], 'total students': [19]})

# %%
df1
# Out:
#            course  grade  total students
# 0  social science     10              19

# %%
df2 = pd.concat([df, df1])

# %%
df2
# Out:
#            course  grade  total students
# 0            math     10              20
# 1         biology      8              21
# 2              cs      4              14
# 0  social science     10              19

# %%
df2.rename(columns={'course': 'Course', 'grade': 'Grade'}, inplace=True)

# %%
df2
# Out:
#            Course  Grade  total students
# 0            math     10              20
# 1         biology      8              21
# 2              cs      4              14
# 0  social science     10              19

# %% [markdown]
# ### Case 2: upload from file (the most common case)

# %% [markdown]
# ### The social capital atlas

# %% [markdown]
# The dataset provides measures of Social Capital for counties, ZIP codes, high schools, and colleges in the United States based on data from Facebook. The Social Capital Atlas dataset is the result of a collaboration between Meta, Opportunity Insights, and researchers from Harvard, New York University, and Stanford.
#
# We construct three measures of social capital:
#
# - Connectedness - The extent to which people with different characteristics are friends with each other. This includes our main **economic connectedness** measure.
#
# - Cohesiveness - The degree to which friendship networks are clustered into cliques and whether friendships tend to be supported by mutual friends. This includes our clustering and support ratio measures.
#
# - Civic Engagement - Indices of trust or participation in civic organizations. This includes our volunteering rate measure.
#
# A visualization of this data is available here: www.socialcapital.org
#
# Research publications for the Social Capital Atlas dataset are available here:
#
# - [Social Capital I: Measurement and Associations with Economic Mobility](https://www.nature.com/articles/s41586-022-04996-4)
#
# - [Social Capital II: Determinants of Economic Connectedness](https://www.nature.com/articles/s41586-022-04997-3)

# %% [markdown]
# We focus on the data collected at **county level**.

# %%
df_capital = pd.read_csv('./../data/social_capital_county.csv')

# %%
df_capital.head(10)
# Out:
#    county        county_name  num_below_p50   pop2018  ec_county
# 0    1001   Autauga, Alabama      5922.3921   55200.0    0.72077  \
# 1    1003   Baldwin, Alabama     15458.3960  208107.0    0.74313
# 2    1005   Barbour, Alabama      4863.9736   25782.0    0.41366
# 3    1007      Bibb, Alabama      3061.4934   22527.0    0.63152
# 4    1009    Blount, Alabama      6740.9116   57645.0    0.72562
# 5    1011   Bullock, Alabama      2581.3296   10352.0    0.35515
# 6    1013    Butler, Alabama      4092.7781   20025.0    0.46026
# 7    1015   Calhoun, Alabama     15036.1470  115098.0    0.60189
# 8    1017  Chambers, Alabama      5885.4712   33826.0    0.49761
# 9    1019  Cherokee, Alabama      3303.9607   25853.0    0.60461
#
#    ec_se_county  child_ec_county  child_ec_se_county  ec_grp_mem_county
# 0       0.00831          1.11754             0.02467            0.77223  \
# 1       0.00661          0.83064             0.01629            0.76215
# 2       0.00978          0.58541             0.02707            0.35927
# 3       0.01175          0.72265             0.03027            0.68094
# 4       0.00985          0.76096             0.02466            0.79584
# 5       0.01134              NaN                 NaN            0.24803
# 6       0.01039          0.63507             0.03159            0.43619
# 7       0.00711          0.80398             0.01891            0.63921
# 8       0.00869          0.62215             0.02561            0.54166
# 9       0.01188          0.61975             0.03417            0.67164
#
#    ec_high_county  ...  child_exposure_county  child_high_exposure_county
# 0         1.21372  ...                1.14816                     1.19944  \
# 1         1.28302  ...                0.84588                     1.00797
# 2         0.91897  ...                0.63306                     0.71967
# 3         1.06378  ...                0.71433                     0.72395
# 4         1.10569  ...                0.74821                     0.79375
# 5         0.95596  ...                    NaN                         NaN
# 6         0.93106  ...                0.59068                     0.71077
# 7         1.04627  ...                0.79993                     0.89271
# 8         0.91306  ...                0.60910                     0.68218
# 9         0.94985  ...                0.60974                     0.65038
#
#    bias_grp_mem_county  bias_grp_mem_high_county  child_bias_county
# 0              0.05526                  -0.22748            0.02668  \
# 1              0.02950                  -0.21519            0.01802
# 2              0.13457                  -0.34086            0.07528
# 3              0.04108                  -0.27727           -0.01165
# 4              0.00217                  -0.24946           -0.01704
# 5              0.07974                  -0.19417                NaN
# 6              0.09278                  -0.31730           -0.07516
# 7              0.05719                  -0.23771           -0.00507
# 8              0.11264                  -0.23977           -0.02143
# 9              0.02300                  -0.25110           -0.01641
#
#    child_high_bias_county  clustering_county  support_ratio_county
# 0                -0.08229            0.10347               0.98275  \
# 1                -0.05241            0.09624               0.98684
# 2                -0.19714            0.14911               0.99911
# 3                -0.15993            0.14252               0.99716
# 4                -0.08745            0.11243               0.99069
# 5                     NaN            0.18581               1.00000
# 6                -0.12359            0.16094               1.00000
# 7                -0.10307            0.11236               0.99701
# 8                -0.12734            0.13574               0.99759
# 9                -0.09970            0.12273               0.99697
#
#    volunteering_rate_county  civic_organizations_county
# 0                   0.04355                     0.01518
# 1                   0.06117                     0.01526
# 2                   0.02093                     0.01474
# 3                   0.05294                     0.01439
# 4                   0.05704                     0.01724
# 5                   0.01713                     0.00975
# 6                   0.03807                     0.01286
# 7                   0.05313                     0.01739
# 8                   0.02566                     0.01098
# 9                   0.04666                     0.01796
#
# [10 rows x 26 columns]

# %%
df_capital.columns
# Out:
# Index(['county', 'county_name', 'num_below_p50', 'pop2018', 'ec_county',
#        'ec_se_county', 'child_ec_county', 'child_ec_se_county',
#        'ec_grp_mem_county', 'ec_high_county', 'ec_high_se_county',
#        'child_high_ec_county', 'child_high_ec_se_county',
#        'ec_grp_mem_high_county', 'exposure_grp_mem_county',
#        'exposure_grp_mem_high_county', 'child_exposure_county',
#        'child_high_exposure_county', 'bias_grp_mem_county',
#        'bias_grp_mem_high_county', 'child_bias_county',
#        'child_high_bias_county', 'clustering_county', 'support_ratio_county',
#        'volunteering_rate_county', 'civic_organizations_county'],
#       dtype='object')

# %%
df_capital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3089 entries, 0 to 3088
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   county                        3089 non-null   int64
#  1   county_name                   3089 non-null   object
#  2   num_below_p50                 3087 non-null   float64
#  3   pop2018                       2983 non-null   float64
#  4   ec_county                     3018 non-null   float64
#  5   ec_se_county                  3018 non-null   float64
#  6   child_ec_county               2729 non-null   float64
#  7   child_ec_se_county            2729 non-null   float64
#  8   ec_grp_mem_county             3012 non-null   float64
#  9   ec_high_county                3018 non-null   float64
#  10  ec_high_se_county             3018 non-null   float64
#  11  child_high_ec_county          2729 non-null   float64
#  12  child_high_ec_se_county       2729 non-null   float64
#  13  ec_grp_mem_high_county        3012 non-null   float64
#  14  exposure_grp_mem_county       3012 non-null   float64
#  15  exposure_grp_mem_high_county  3012 non-null   float64
#  16  child_exposure_county         2729 non-null   float64
#  17  child_high_exposure_county    2729 non-null   float64
#  18  bias_grp_mem_county           3012 non-null   float64
#  19  bias_grp_mem_high_county      3012 non-null   float64
#  20  child_bias_county             2729 non-null   float64
#  21  child_high_bias_county        2729 non-null   float64
#  22  clustering_county             3089 non-null   float64
#  23  support_ratio_county          3089 non-null   float64
#  24  volunteering_rate_county      3089 non-null   float64
#  25  civic_organizations_county    3089 non-null   float64
# dtypes: float64(24), int64(1), object(1)
# memory usage: 627.6+ KB

# %% [markdown]
# We note there are some NaN values

# %%
df_capital.isnull().sum()
# Out:
# county                            0
# county_name                       0
# num_below_p50                     2
# pop2018                         106
# ec_county                        71
# ec_se_county                     71
# child_ec_county                 360
# child_ec_se_county              360
# ec_grp_mem_county                77
# ec_high_county                   71
# ec_high_se_county                71
# child_high_ec_county            360
# child_high_ec_se_county         360
# ec_grp_mem_high_county           77
# exposure_grp_mem_county          77
# exposure_grp_mem_high_county     77
# child_exposure_county           360
# child_high_exposure_county      360
# bias_grp_mem_county              77
# bias_grp_mem_high_county         77
# child_bias_county               360
# child_high_bias_county          360
# clustering_county                 0
# support_ratio_county              0
# volunteering_rate_county          0
# civic_organizations_county        0
# dtype: int64

# %%
df_capital.describe()
# Out:
#              county  num_below_p50       pop2018    ec_county  ec_se_county
# count   3089.000000   3.087000e+03  2.983000e+03  3018.000000   3018.000000  \
# mean   30218.783101   1.059956e+04  1.080104e+05     0.814464      0.013409
# std    15138.796297   4.164424e+04  3.377826e+05     0.177126      0.006176
# min     1001.000000   5.230174e+01  5.440000e+02     0.294690      0.004360
# 25%    18161.000000   1.626969e+03  1.263000e+04     0.695607      0.009142
# 50%    29135.000000   3.353481e+03  2.788700e+04     0.806830      0.011900
# 75%    45049.000000   7.326979e+03  7.272850e+04     0.936783      0.015800
# max    56045.000000   1.576718e+06  1.009805e+07     1.359700      0.050230
#
#        child_ec_county  child_ec_se_county  ec_grp_mem_county  ec_high_county
# count      2729.000000         2729.000000        3012.000000     3018.000000  \
# mean          0.825335            0.032464           0.850302        1.252636
# std           0.221210            0.013225           0.213428        0.176560
# min           0.221880            0.011990           0.187420        0.700620
# 25%           0.678750            0.022390           0.708260        1.134863
# 50%           0.815510            0.029900           0.840455        1.258200
# 75%           0.962130            0.039900           0.996458        1.384345
# max           1.611360            0.091120           1.475880        1.715070
#
#        ec_high_se_county  ...  child_exposure_county
# count        3018.000000  ...            2729.000000  \
# mean            0.014754  ...               0.827984
# std             0.006231  ...               0.226322
# min             0.004750  ...               0.216910
# 25%             0.010060  ...               0.673550
# 50%             0.013495  ...               0.816630
# 75%             0.017788  ...               0.964820
# max             0.050990  ...               1.634340
#
#        child_high_exposure_county  bias_grp_mem_county
# count                 2729.000000          3012.000000  \
# mean                     0.885009             0.064161
# std                      0.248020             0.050633
# min                      0.217280            -0.108090
# 25%                      0.715310             0.030808
# 50%                      0.868680             0.063970
# 75%                      1.040880             0.095450
# max                      1.655150             0.334570
#
#        bias_grp_mem_high_county  child_bias_county  child_high_bias_county
# count               3012.000000        2729.000000             2729.000000  \
# mean                  -0.187968           0.001222               -0.085386
# std                    0.064644           0.033337                0.048938
# min                   -0.536180          -0.144020               -0.370950
# 25%                   -0.221698          -0.018260               -0.111190
# 50%                   -0.179075           0.001960               -0.079100
# 75%                   -0.143335           0.019880               -0.052200
# max                   -0.043250           0.162700                0.069830
#
#        clustering_county  support_ratio_county  volunteering_rate_county
# count        3089.000000           3089.000000               3089.000000  \
# mean            0.116456              0.988901                  0.078068
# std             0.020364              0.015467                  0.034841
# min             0.071620              0.696760                  0.009650
# 25%             0.102690              0.986830                  0.055280
# 50%             0.114570              0.993740                  0.073280
# 75%             0.127240              0.996720                  0.093960
# max             0.260970              1.000000                  0.308736
#
#        civic_organizations_county
# count                 3089.000000
# mean                     0.019762
# std                      0.009850
# min                      0.003490
# 25%                      0.014020
# 50%                      0.017780
# 75%                      0.023060
# max                      0.195429
#
# [8 rows x 25 columns]

# %%
df_capital.set_index(['county'], inplace=True)

# %%
df_capital.head()
# Out:
#              county_name  num_below_p50   pop2018  ec_county  ec_se_county
# county
# 1001    Autauga, Alabama      5922.3921   55200.0    0.72077       0.00831  \
# 1003    Baldwin, Alabama     15458.3960  208107.0    0.74313       0.00661
# 1005    Barbour, Alabama      4863.9736   25782.0    0.41366       0.00978
# 1007       Bibb, Alabama      3061.4934   22527.0    0.63152       0.01175
# 1009     Blount, Alabama      6740.9116   57645.0    0.72562       0.00985
#
#         child_ec_county  child_ec_se_county  ec_grp_mem_county
# county
# 1001            1.11754             0.02467            0.77223  \
# 1003            0.83064             0.01629            0.76215
# 1005            0.58541             0.02707            0.35927
# 1007            0.72265             0.03027            0.68094
# 1009            0.76096             0.02466            0.79584
#
#         ec_high_county  ec_high_se_county  ...  child_exposure_county
# county                                     ...
# 1001           1.21372            0.01019  ...                1.14816  \
# 1003           1.28302            0.00757  ...                0.84588
# 1005           0.91897            0.02199  ...                0.63306
# 1007           1.06378            0.01476  ...                0.71433
# 1009           1.10569            0.01163  ...                0.74821
#
#         child_high_exposure_county  bias_grp_mem_county
# county
# 1001                       1.19944              0.05526  \
# 1003                       1.00797              0.02950
# 1005                       0.71967              0.13457
# 1007                       0.72395              0.04108
# 1009                       0.79375              0.00217
#
#         bias_grp_mem_high_county  child_bias_county  child_high_bias_county
# county
# 1001                    -0.22748            0.02668                -0.08229  \
# 1003                    -0.21519            0.01802                -0.05241
# 1005                    -0.34086            0.07528                -0.19714
# 1007                    -0.27727           -0.01165                -0.15993
# 1009                    -0.24946           -0.01704                -0.08745
#
#         clustering_county  support_ratio_county  volunteering_rate_county
# county
# 1001              0.10347               0.98275                   0.04355  \
# 1003              0.09624               0.98684                   0.06117
# 1005              0.14911               0.99911                   0.02093
# 1007              0.14252               0.99716                   0.05294
# 1009              0.11243               0.99069                   0.05704
#
#         civic_organizations_county
# county
# 1001                       0.01518
# 1003                       0.01526
# 1005                       0.01474
# 1007                       0.01439
# 1009                       0.01724
#
# [5 rows x 25 columns]

# %%
df_capital.reset_index(drop=False, inplace=True)

# %%
df_capital.head()
# Out:
#    county       county_name  num_below_p50   pop2018  ec_county  ec_se_county
# 0    1001  Autauga, Alabama      5922.3921   55200.0    0.72077       0.00831  \
# 1    1003  Baldwin, Alabama     15458.3960  208107.0    0.74313       0.00661
# 2    1005  Barbour, Alabama      4863.9736   25782.0    0.41366       0.00978
# 3    1007     Bibb, Alabama      3061.4934   22527.0    0.63152       0.01175
# 4    1009   Blount, Alabama      6740.9116   57645.0    0.72562       0.00985
#
#    child_ec_county  child_ec_se_county  ec_grp_mem_county  ec_high_county
# 0          1.11754             0.02467            0.77223         1.21372  \
# 1          0.83064             0.01629            0.76215         1.28302
# 2          0.58541             0.02707            0.35927         0.91897
# 3          0.72265             0.03027            0.68094         1.06378
# 4          0.76096             0.02466            0.79584         1.10569
#
#    ...  child_exposure_county  child_high_exposure_county
# 0  ...                1.14816                     1.19944  \
# 1  ...                0.84588                     1.00797
# 2  ...                0.63306                     0.71967
# 3  ...                0.71433                     0.72395
# 4  ...                0.74821                     0.79375
#
#    bias_grp_mem_county  bias_grp_mem_high_county  child_bias_county
# 0              0.05526                  -0.22748            0.02668  \
# 1              0.02950                  -0.21519            0.01802
# 2              0.13457                  -0.34086            0.07528
# 3              0.04108                  -0.27727           -0.01165
# 4              0.00217                  -0.24946           -0.01704
#
#    child_high_bias_county  clustering_county  support_ratio_county
# 0                -0.08229            0.10347               0.98275  \
# 1                -0.05241            0.09624               0.98684
# 2                -0.19714            0.14911               0.99911
# 3                -0.15993            0.14252               0.99716
# 4                -0.08745            0.11243               0.99069
#
#    volunteering_rate_county  civic_organizations_county
# 0                   0.04355                     0.01518
# 1                   0.06117                     0.01526
# 2                   0.02093                     0.01474
# 3                   0.05294                     0.01439
# 4                   0.05704                     0.01724
#
# [5 rows x 26 columns]

# %%
df_capital['ec_county']
# Out:
# 0       0.72077
# 1       0.74313
# 2       0.41366
# 3       0.63152
# 4       0.72562
#          ...
# 3084    0.96235
# 3085    1.07623
# 3086    0.95452
# 3087    0.90667
# 3088    0.97840
# Name: ec_county, Length: 3089, dtype: float64

# %%
df_capital.ec_county.describe()
# Out:
# count    3018.000000
# mean        0.814464
# std         0.177126
# min         0.294690
# 25%         0.695607
# 50%         0.806830
# 75%         0.936783
# max         1.359700
# Name: ec_county, dtype: float64

# %%
df_capital['ec_county'].describe()
# Out:
# count    3018.000000
# mean        0.814464
# std         0.177126
# min         0.294690
# 25%         0.695607
# 50%         0.806830
# 75%         0.936783
# max         1.359700
# Name: ec_county, dtype: float64

# %%
df_capital['ec_county'].max(), df_capital['ec_county'].min()
# Out:
# (1.3597, 0.29469001)

# %%
df_capital['ec_county'].mean()
# Out:
# 0.8144641210868125

# %% [markdown]
# We can add a new column based on operations with the existing columns.

# %%
df_capital['perc_pop'] = df_capital['pop2018']*100/df_capital.pop2018.sum()

# %%
df_capital.tail()
# Out:
#       county          county_name  num_below_p50  pop2018  ec_county
# 3084   56037  Sweetwater, Wyoming     2402.96900  44117.0    0.96235  \
# 3085   56039       Teton, Wyoming      783.24982  23059.0    1.07623
# 3086   56041       Uinta, Wyoming     2174.06180  20609.0    0.95452
# 3087   56043    Washakie, Wyoming      872.51544   8129.0    0.90667
# 3088   56045      Weston, Wyoming      635.28436   7100.0    0.97840
#
#       ec_se_county  child_ec_county  child_ec_se_county  ec_grp_mem_county
# 3084       0.01280          1.14781             0.02794            1.13449  \
# 3085       0.01744          1.23113             0.04692            1.13296
# 3086       0.01404          1.04595             0.03455            0.92831
# 3087       0.01928          0.90794             0.04962            0.78223
# 3088       0.02036          1.09118             0.05823            0.93135
#
#       ec_high_county  ...  child_high_exposure_county  bias_grp_mem_county
# 3084         1.32399  ...                     1.12907              0.09519  \
# 3085         1.63551  ...                     1.35341              0.14337
# 3086         1.32040  ...                     1.06284              0.13816
# 3087         1.29208  ...                     0.88589              0.06667
# 3088         1.28553  ...                     1.05526              0.02279
#
#       bias_grp_mem_high_county  child_bias_county  child_high_bias_county
# 3084                  -0.12030           -0.02333                -0.08683  \
# 3085                  -0.11958            0.07346                -0.07364
# 3086                  -0.12194            0.00808                -0.06074
# 3087                  -0.20435           -0.02615                -0.06076
# 3088                  -0.17229           -0.05606                -0.04609
#
#       clustering_county  support_ratio_county  volunteering_rate_county
# 3084            0.10809               0.99710                   0.07321  \
# 3085            0.09253               0.98648                   0.09747
# 3086            0.11204               0.99479                   0.06942
# 3087            0.11592               0.99708                   0.05843
# 3088            0.11927               0.99730                   0.13635
#
#       civic_organizations_county  perc_pop
# 3084                     0.01225  0.013693
# 3085                     0.03223  0.007157
# 3086                     0.01222  0.006396
# 3087                     0.03512  0.002523
# 3088                     0.02375  0.002204
#
# [5 rows x 27 columns]

# %%
df_capital.perc_pop.sum()
# Out:
# 99.99999999999999

# %% [markdown]
# ## State based analysis
#
# We would like to add a new column that identifies the State. We can get each state name from the name of the county, which is a string.

# %%
df_capital[['county','state']] = df_capital['county_name'].str.split(', ', expand=True)

# %%
df_capital
# Out:
#           county          county_name  num_below_p50   pop2018  ec_county
# 0        Autauga     Autauga, Alabama     5922.39210   55200.0    0.72077  \
# 1        Baldwin     Baldwin, Alabama    15458.39600  208107.0    0.74313
# 2        Barbour     Barbour, Alabama     4863.97360   25782.0    0.41366
# 3           Bibb        Bibb, Alabama     3061.49340   22527.0    0.63152
# 4         Blount      Blount, Alabama     6740.91160   57645.0    0.72562
# ...          ...                  ...            ...       ...        ...
# 3084  Sweetwater  Sweetwater, Wyoming     2402.96900   44117.0    0.96235
# 3085       Teton       Teton, Wyoming      783.24982   23059.0    1.07623
# 3086       Uinta       Uinta, Wyoming     2174.06180   20609.0    0.95452
# 3087    Washakie    Washakie, Wyoming      872.51544    8129.0    0.90667
# 3088      Weston      Weston, Wyoming      635.28436    7100.0    0.97840
#
#       ec_se_county  child_ec_county  child_ec_se_county  ec_grp_mem_county
# 0          0.00831          1.11754             0.02467            0.77223  \
# 1          0.00661          0.83064             0.01629            0.76215
# 2          0.00978          0.58541             0.02707            0.35927
# 3          0.01175          0.72265             0.03027            0.68094
# 4          0.00985          0.76096             0.02466            0.79584
# ...            ...              ...                 ...                ...
# 3084       0.01280          1.14781             0.02794            1.13449
# 3085       0.01744          1.23113             0.04692            1.13296
# 3086       0.01404          1.04595             0.03455            0.92831
# 3087       0.01928          0.90794             0.04962            0.78223
# 3088       0.02036          1.09118             0.05823            0.93135
#
#       ec_high_county  ...  bias_grp_mem_county  bias_grp_mem_high_county
# 0            1.21372  ...              0.05526                  -0.22748  \
# 1            1.28302  ...              0.02950                  -0.21519
# 2            0.91897  ...              0.13457                  -0.34086
# 3            1.06378  ...              0.04108                  -0.27727
# 4            1.10569  ...              0.00217                  -0.24946
# ...              ...  ...                  ...                       ...
# 3084         1.32399  ...              0.09519                  -0.12030
# 3085         1.63551  ...              0.14337                  -0.11958
# 3086         1.32040  ...              0.13816                  -0.12194
# 3087         1.29208  ...              0.06667                  -0.20435
# 3088         1.28553  ...              0.02279                  -0.17229
#
#       child_bias_county  child_high_bias_county  clustering_county
# 0               0.02668                -0.08229            0.10347  \
# 1               0.01802                -0.05241            0.09624
# 2               0.07528                -0.19714            0.14911
# 3              -0.01165                -0.15993            0.14252
# 4              -0.01704                -0.08745            0.11243
# ...                 ...                     ...                ...
# 3084           -0.02333                -0.08683            0.10809
# 3085            0.07346                -0.07364            0.09253
# 3086            0.00808                -0.06074            0.11204
# 3087           -0.02615                -0.06076            0.11592
# 3088           -0.05606                -0.04609            0.11927
#
#       support_ratio_county  volunteering_rate_county
# 0                  0.98275                   0.04355  \
# 1                  0.98684                   0.06117
# 2                  0.99911                   0.02093
# 3                  0.99716                   0.05294
# 4                  0.99069                   0.05704
# ...                    ...                       ...
# 3084               0.99710                   0.07321
# 3085               0.98648                   0.09747
# 3086               0.99479                   0.06942
# 3087               0.99708                   0.05843
# 3088               0.99730                   0.13635
#
#       civic_organizations_county  perc_pop    state
# 0                        0.01518  0.017132  Alabama
# 1                        0.01526  0.064590  Alabama
# 2                        0.01474  0.008002  Alabama
# 3                        0.01439  0.006992  Alabama
# 4                        0.01724  0.017891  Alabama
# ...                          ...       ...      ...
# 3084                     0.01225  0.013693  Wyoming
# 3085                     0.03223  0.007157  Wyoming
# 3086                     0.01222  0.006396  Wyoming
# 3087                     0.03512  0.002523  Wyoming
# 3088                     0.02375  0.002204  Wyoming
#
# [3089 rows x 28 columns]

# %%
df_capital.drop('county_name', axis=1, inplace=True)

# %%
df_capital
# Out:
#           county  num_below_p50   pop2018  ec_county  ec_se_county
# 0        Autauga     5922.39210   55200.0    0.72077       0.00831  \
# 1        Baldwin    15458.39600  208107.0    0.74313       0.00661
# 2        Barbour     4863.97360   25782.0    0.41366       0.00978
# 3           Bibb     3061.49340   22527.0    0.63152       0.01175
# 4         Blount     6740.91160   57645.0    0.72562       0.00985
# ...          ...            ...       ...        ...           ...
# 3084  Sweetwater     2402.96900   44117.0    0.96235       0.01280
# 3085       Teton      783.24982   23059.0    1.07623       0.01744
# 3086       Uinta     2174.06180   20609.0    0.95452       0.01404
# 3087    Washakie      872.51544    8129.0    0.90667       0.01928
# 3088      Weston      635.28436    7100.0    0.97840       0.02036
#
#       child_ec_county  child_ec_se_county  ec_grp_mem_county  ec_high_county
# 0             1.11754             0.02467            0.77223         1.21372  \
# 1             0.83064             0.01629            0.76215         1.28302
# 2             0.58541             0.02707            0.35927         0.91897
# 3             0.72265             0.03027            0.68094         1.06378
# 4             0.76096             0.02466            0.79584         1.10569
# ...               ...                 ...                ...             ...
# 3084          1.14781             0.02794            1.13449         1.32399
# 3085          1.23113             0.04692            1.13296         1.63551
# 3086          1.04595             0.03455            0.92831         1.32040
# 3087          0.90794             0.04962            0.78223         1.29208
# 3088          1.09118             0.05823            0.93135         1.28553
#
#       ec_high_se_county  ...  bias_grp_mem_county  bias_grp_mem_high_county
# 0               0.01019  ...              0.05526                  -0.22748  \
# 1               0.00757  ...              0.02950                  -0.21519
# 2               0.02199  ...              0.13457                  -0.34086
# 3               0.01476  ...              0.04108                  -0.27727
# 4               0.01163  ...              0.00217                  -0.24946
# ...                 ...  ...                  ...                       ...
# 3084            0.01177  ...              0.09519                  -0.12030
# 3085            0.00848  ...              0.14337                  -0.11958
# 3086            0.01351  ...              0.13816                  -0.12194
# 3087            0.02298  ...              0.06667                  -0.20435
# 3088            0.02013  ...              0.02279                  -0.17229
#
#       child_bias_county  child_high_bias_county  clustering_county
# 0               0.02668                -0.08229            0.10347  \
# 1               0.01802                -0.05241            0.09624
# 2               0.07528                -0.19714            0.14911
# 3              -0.01165                -0.15993            0.14252
# 4              -0.01704                -0.08745            0.11243
# ...                 ...                     ...                ...
# 3084           -0.02333                -0.08683            0.10809
# 3085            0.07346                -0.07364            0.09253
# 3086            0.00808                -0.06074            0.11204
# 3087           -0.02615                -0.06076            0.11592
# 3088           -0.05606                -0.04609            0.11927
#
#       support_ratio_county  volunteering_rate_county
# 0                  0.98275                   0.04355  \
# 1                  0.98684                   0.06117
# 2                  0.99911                   0.02093
# 3                  0.99716                   0.05294
# 4                  0.99069                   0.05704
# ...                    ...                       ...
# 3084               0.99710                   0.07321
# 3085               0.98648                   0.09747
# 3086               0.99479                   0.06942
# 3087               0.99708                   0.05843
# 3088               0.99730                   0.13635
#
#       civic_organizations_county  perc_pop    state
# 0                        0.01518  0.017132  Alabama
# 1                        0.01526  0.064590  Alabama
# 2                        0.01474  0.008002  Alabama
# 3                        0.01439  0.006992  Alabama
# 4                        0.01724  0.017891  Alabama
# ...                          ...       ...      ...
# 3084                     0.01225  0.013693  Wyoming
# 3085                     0.03223  0.007157  Wyoming
# 3086                     0.01222  0.006396  Wyoming
# 3087                     0.03512  0.002523  Wyoming
# 3088                     0.02375  0.002204  Wyoming
#
# [3089 rows x 27 columns]

# %% [markdown]
# We can save the data of one state in another dataframe

# %%
df_ny=df_capital[ df_capital['state']=='New York' ]

# %%
df_ny
# Out:
#            county  num_below_p50    pop2018  ec_county  ec_se_county
# 1806       Albany     19730.4530   307426.0    0.87391       0.00696  \
# 1807     Allegany      6156.7988    47025.0    0.77830       0.01046
# 1808        Bronx    306567.2200  1437872.0    0.68067       0.00582
# 1809       Broome     17773.2990   194402.0    0.81245       0.00765
# 1810  Cattaraugus     10743.7870    77686.0    0.75653       0.00883
# ...           ...            ...        ...        ...           ...
# 1863   Washington      7010.4185    61828.0    0.83695       0.00946
# 1864        Wayne      9204.1865    90856.0    0.84524       0.00851
# 1865  Westchester     72428.8670   968815.0    0.81660       0.00707
# 1866      Wyoming      4121.3638    40565.0    0.91835       0.01080
# 1867        Yates      3377.3796    25009.0    0.83705       0.01365
#
#       child_ec_county  child_ec_se_county  ec_grp_mem_county  ec_high_county
# 1806          1.07797             0.01660            0.93122         1.46298  \
# 1807          0.72988             0.02813            0.77641         1.17528
# 1808          0.64668             0.02103            0.71643         1.05966
# 1809          0.95977             0.01779            0.83284         1.32753
# 1810          0.79904             0.02362            0.74164         1.17481
# ...               ...                 ...                ...             ...
# 1863          0.90398             0.02653            0.86633         1.24874
# 1864          0.88739             0.02070            0.88855         1.28471
# 1865          1.12902             0.01667            0.83242         1.54990
# 1866          0.83573             0.03192            0.98200         1.24324
# 1867          0.86294             0.03091            0.84815         1.24484
#
#       ec_high_se_county  ...  bias_grp_mem_county  bias_grp_mem_high_county
# 1806            0.00766  ...              0.09544                  -0.10858  \
# 1807            0.01360  ...              0.05611                  -0.16242
# 1808            0.00972  ...              0.07198                  -0.05801
# 1809            0.00932  ...              0.11081                  -0.17814
# 1810            0.01122  ...              0.07970                  -0.18230
# ...                 ...  ...                  ...                       ...
# 1863            0.01102  ...              0.10965                  -0.14908
# 1864            0.00986  ...              0.07851                  -0.14922
# 1865            0.00844  ...              0.15073                  -0.07636
# 1866            0.01149  ...              0.03437                  -0.14278
# 1867            0.01522  ...              0.06515                  -0.15875
#
#       child_bias_county  child_high_bias_county  clustering_county
# 1806            0.02809                -0.03760            0.09890  \
# 1807           -0.04814                -0.07987            0.11585
# 1808           -0.03836                -0.02937            0.07162
# 1809            0.01046                -0.08075            0.10276
# 1810            0.00109                -0.10368            0.11800
# ...                 ...                     ...                ...
# 1863           -0.00986                -0.06501            0.11018
# 1864           -0.00957                -0.06865            0.10943
# 1865            0.04014                -0.03532            0.09368
# 1866           -0.00098                -0.06918            0.12014
# 1867            0.00085                -0.07964            0.12251
#
#       support_ratio_county  volunteering_rate_county
# 1806               0.97807                   0.08142  \
# 1807               0.99304                   0.07390
# 1808               0.93306                   0.02304
# 1809               0.99236                   0.07719
# 1810               0.99380                   0.07353
# ...                    ...                       ...
# 1863               0.98862                   0.12213
# 1864               0.98842                   0.09101
# 1865               0.96771                   0.05070
# 1866               0.99257                   0.06816
# 1867               0.99614                   0.08529
#
#       civic_organizations_county  perc_pop     state
# 1806                     0.02288  0.095416  New York
# 1807                     0.02430  0.014595  New York
# 1808                     0.00649  0.446274  New York
# 1809                     0.01678  0.060337  New York
# 1810                     0.01886  0.024111  New York
# ...                          ...       ...       ...
# 1863                     0.01706  0.019190  New York
# 1864                     0.01574  0.028199  New York
# 1865                     0.01653  0.300692  New York
# 1866                     0.02165  0.012590  New York
# 1867                     0.03253  0.007762  New York
#
# [62 rows x 27 columns]

# %%
df_ny[ df_ny['child_ec_county'].isnull() ]
# Out:
#         county  num_below_p50  pop2018  ec_county  ec_se_county
# 1826  Hamilton      576.20111   4575.0     1.0166       0.02531  \
#
#       child_ec_county  child_ec_se_county  ec_grp_mem_county  ec_high_county
# 1826              NaN                 NaN            1.03733         1.39314  \
#
#       ec_high_se_county  ...  bias_grp_mem_county  bias_grp_mem_high_county
# 1826            0.02669  ...             -0.02234                  -0.11121  \
#
#       child_bias_county  child_high_bias_county  clustering_county
# 1826                NaN                     NaN            0.11687  \
#
#       support_ratio_county  volunteering_rate_county
# 1826               0.99584                   0.07545  \
#
#       civic_organizations_county  perc_pop     state
# 1826                     0.07916   0.00142  New York
#
# [1 rows x 27 columns]

# %% [markdown]
# Or compute the mean of the EC Index by each state with a **groupby**

# %%
df_capital.groupby(['state'])['ec_county'].mean()
# Out:
# state
# Alabama                 0.595470
# Alaska                  0.988170
# Arizona                 0.691928
# Arkansas                0.689512
# California              0.807316
# Colorado                0.951726
# Connecticut             0.948693
# Delaware                0.781613
# District of Columbia    0.996160
# Florida                 0.664965
# Georgia                 0.607236
# Hawaii                  1.041255
# Idaho                   0.852070
# Illinois                0.840682
# Indiana                 0.823437
# Iowa                    0.984454
# Kansas                  0.940320
# Kentucky                0.825159
# Louisiana               0.699572
# Maine                   0.841684
# Maryland                0.948747
# Massachusetts           0.928555
# Michigan                0.803008
# Minnesota               1.047906
# Mississippi             0.634397
# Missouri                0.845587
# Montana                 0.895603
# Nebraska                0.988439
# Nevada                  0.838435
# New Hampshire           1.087421
# New Jersey              0.894471
# New Mexico              0.627407
# New York                0.839834
# North Carolina          0.633976
# North Dakota            1.054993
# Ohio                    0.806546
# Oklahoma                0.789574
# Oregon                  0.794841
# Pennsylvania            0.862979
# Rhode Island            1.023338
# South Carolina          0.563833
# South Dakota            0.953253
# Tennessee               0.679045
# Texas                   0.766790
# Utah                    1.021165
# Vermont                 0.945382
# Virginia                0.824224
# Washington              0.868723
# West Virginia           0.783733
# Wisconsin               0.963143
# Wyoming                 0.988113
# Name: ec_county, dtype: float64

# %%
df_med_state = df_capital.groupby(['state'])['ec_county'].median()

# %%
df_med_state = df_med_state.to_frame()

# %%
df_med_state
# Out:
#                       ec_county
# state
# Alabama                0.599175
# Alaska                 1.040115
# Arizona                0.715720
# Arkansas               0.704260
# California             0.800080
# Colorado               0.937605
# Connecticut            0.972300
# Delaware               0.792910
# District of Columbia   0.996160
# Florida                0.668010
# Georgia                0.577825
# Hawaii                 1.075315
# Idaho                  0.862720
# Illinois               0.844915
# Indiana                0.818605
# Iowa                   0.998330
# Kansas                 0.958110
# Kentucky               0.838035
# Louisiana              0.692090
# Maine                  0.827665
# Maryland               0.958940
# Massachusetts          0.922825
# Michigan               0.786515
# Minnesota              1.062540
# Mississippi            0.647440
# Missouri               0.846685
# Montana                0.932860
# Nebraska               1.020905
# Nevada                 0.829660
# New Hampshire          1.083120
# New Jersey             0.942680
# New Mexico             0.629110
# New York               0.834655
# North Carolina         0.628570
# North Dakota           1.111155
# Ohio                   0.811940
# Oklahoma               0.783880
# Oregon                 0.786190
# Pennsylvania           0.845410
# Rhode Island           1.029000
# South Carolina         0.533780
# South Dakota           1.014720
# Tennessee              0.675520
# Texas                  0.774120
# Utah                   1.022990
# Vermont                0.956825
# Virginia               0.815840
# Washington             0.849380
# West Virginia          0.770170
# Wisconsin              0.961075
# Wyoming                0.974500

# %%
df_med_state.T
# Out:
# state       Alabama    Alaska  Arizona  Arkansas  California  Colorado
# ec_county  0.599175  1.040115  0.71572   0.70426     0.80008  0.937605  \
#
# state      Connecticut  Delaware  District of Columbia  Florida  ...
# ec_county       0.9723   0.79291               0.99616  0.66801  ...  \
#
# state      South Dakota  Tennessee    Texas     Utah   Vermont  Virginia
# ec_county       1.01472    0.67552  0.77412  1.02299  0.956825   0.81584  \
#
# state      Washington  West Virginia  Wisconsin  Wyoming
# ec_county     0.84938        0.77017   0.961075   0.9745
#
# [1 rows x 51 columns]

# %%
df_med_state[df_med_state.ec_county > 1]
# Out:
#                ec_county
# state
# Alaska          1.040115
# Hawaii          1.075315
# Minnesota       1.062540
# Nebraska        1.020905
# New Hampshire   1.083120
# North Dakota    1.111155
# Rhode Island    1.029000
# South Dakota    1.014720
# Utah            1.022990

# %%
df_med_state[df_med_state.ec_county < 0.7]
# Out:
#                 ec_county
# state
# Alabama          0.599175
# Florida          0.668010
# Georgia          0.577825
# Louisiana        0.692090
# Mississippi      0.647440
# New Mexico       0.629110
# North Carolina   0.628570
# South Carolina   0.533780
# Tennessee        0.675520

# %% [markdown]
# # Matplotlib and plotting

# %% [markdown]
# Matplotlib is an excellent 2D and 3D graphics library for generating scientific figures. Some of the many advantages of this library include:
#
# * Easy to get started
# * Support for $\LaTeX$ formatted labels and texts
# * Great control of every element in a figure, including figure size and DPI.
# * High-quality output in many formats, including PNG, PDF, SVG, EPS, and PGF.
# * GUI for interactively exploring figures *and* support for headless generation of figure files (useful for batch jobs).
#
# All aspects of the figure can be controlled *programmatically*. This is important for reproducibility and convenient when one needs to regenerate the figure with updated data or change its appearance.
#
# More information at the Matplotlib web page: http://matplotlib.org/

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# Let's start with a very basic plot

# %%
x = np.linspace(0, 5, 10)
y = x ** 2

# %%
x
# Out:
# array([0.        , 0.55555556, 1.11111111, 1.66666667, 2.22222222,
#        2.77777778, 3.33333333, 3.88888889, 4.44444444, 5.        ])

# %%
y
# Out:
# array([ 0.        ,  0.30864198,  1.2345679 ,  2.77777778,  4.9382716 ,
#         7.71604938, 11.11111111, 15.12345679, 19.75308642, 25.        ])

# %%
plt.figure(figsize=(6,4))

plt.plot(x, y, 'r')

plt.xlabel('x', fontsize=18)
plt.ylabel('y', fontsize=18)

plt.title('$y = x^2$')
# Out:
# Text(0.5, 1.0, '$y = x^2$')

# %% [markdown]
# Now, let's plot some interesting quantities of our dataset.

# %% [markdown]
# ## Histograms

# %%
df_med_state.ec_county.hist()
# Out:
# <Axes: >

# %% [markdown]
# This is quite rough... Let's make it look a bit better by considering the original dataframe

# %%
plt.figure(figsize=(8,6))

df_capital.ec_county.hist(bins=100, density=True, color='darkslateblue')

plt.xlabel('Economic connectedness (counties)', fontsize=18)
plt.ylabel('Probability', fontsize=18)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.grid(False)

# %% [markdown]
# ## Scatterplots

# %%
plt.figure(figsize=(8,6))
plt.plot( df_capital['ec_county'], df_capital['volunteering_rate_county'], 'o', markersize=3, color='mediumturquoise')

plt.xlabel('EC index', fontsize=18)
plt.ylabel('Volunteering rate', fontsize=18)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# Out:
# (array([-0.05,  0.  ,  0.05,  0.1 ,  0.15,  0.2 ,  0.25,  0.3 ]),
#  [Text(0, -0.05, '−0.05'),
#   Text(0, 0.0, '0.00'),
#   Text(0, 0.05, '0.05'),
#   Text(0, 0.10000000000000002, '0.10'),
#   Text(0, 0.15000000000000002, '0.15'),
#   Text(0, 0.2, '0.20'),
#   Text(0, 0.25000000000000006, '0.25'),
#   Text(0, 0.30000000000000004, '0.30')])

# %% [markdown]
# Let's compute the Pearson correlation coefficient between the two variables

# %%
df_capital['ec_county'].corr(df_capital['volunteering_rate_county'])
# Out:
# 0.3900491385075802

# %% [markdown]
# # Multiple panels plots

# %%
fig, ax = plt.subplots(2, 2, figsize=(10,7))

ax=ax.flatten() #we flatten the axis to a one-dimensional array

ax[0].scatter(df_capital['ec_county'], df_capital['volunteering_rate_county'], color='mediumturquoise', s=3)
ax[0].set_xlabel('EC Index')
ax[0].set_ylabel('Volunteering Rate')

ax[1].scatter(df_capital['ec_county'], df_capital['clustering_county'], color='navy', s=3)
ax[1].set_xlabel('EC Index')
ax[1].set_ylabel('Clustering')

ax[2].scatter(df_capital['ec_county'], df_capital['ec_high_county'], color='slategrey', s=3)
ax[2].set_xlabel('EC Index')
ax[2].set_ylabel('High EC Index')

ax[3].scatter(df_capital['ec_county'], df_capital['support_ratio_county'], color='coral', s=3)
ax[3].set_xlabel('EC Index')
ax[3].set_ylabel('Supporting Ratio')
# Out:
# Text(0, 0.5, 'Supporting Ratio')

# %% [markdown]
# # Seaborn

# %% [markdown]
# Seaborn is a Python visualization library based on matplotlib. It provides a high-level interface for drawing attractive statistical graphics.
#
# https://seaborn.pydata.org/

# %%
import seaborn as sns

# %%
plt.figure(figsize=(6,12))

sns.boxplot(data=df_capital, x="ec_county", y="state")
# Out:
# <Axes: xlabel='ec_county', ylabel='state'>

# %%
plt.figure(figsize=(6,13))


sns.violinplot(data=df_capital, x="ec_county", y="state")
# Out:
# <Axes: xlabel='ec_county', ylabel='state'>

# %%
df_sel = df_capital[['ec_county','ec_high_county','clustering_county','volunteering_rate_county']]

# %%
df_sel=df_sel.dropna()

# %%
df_corr = df_sel.corr()

# %%
df_corr
# Out:
#                           ec_county  ec_high_county  clustering_county
# ec_county                  1.000000        0.834422          -0.270103  \
# ec_high_county             0.834422        1.000000          -0.467865
# clustering_county         -0.270103       -0.467865           1.000000
# volunteering_rate_county   0.390049        0.276714          -0.023893
#
#                           volunteering_rate_county
# ec_county                                 0.390049
# ec_high_county                            0.276714
# clustering_county                        -0.023893
# volunteering_rate_county                  1.000000

# %%
sns.heatmap(df_corr, vmin=-1, vmax=1, cmap='mako', annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df_sel)
