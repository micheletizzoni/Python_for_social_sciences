# %% [markdown]
# ---
# # Introduzione ai big data e ai metodi computazionali
#
#
# # Esercitazione - Esempio di prova d'esame
#
# Data: 26 maggio 2026
#
# Autori: Michele Tizzoni & Marco Tonin
#
# ---

# %% [markdown]
# # Istruzioni

# %% [markdown]
# La prova consiste in 6 esercizi elencati qui di seguito.
#
# Ad ogni esercizio è assegnato un punteggio di 3 (tre) punti. Tre punti vengono assegnati per una soluzione completa e corretta.
# Uno o due punti possono essere assegnati se la soluzione è impostata correttamente o se l'esercizio è risolto parzialmente.
#
# E' consigliato aggiungere commenti alle soluzioni proposte, in modo da spiegare che cosa dovrebbe fare il codice che scrivete.
#
# La prova si considera superata con un punteggio finale di 11/18.
#
# A prova conclusa, salvate il file con le vostre soluzioni con il nome "Prova d'esame [Nome] [Cognome].ipynb".

# %% [markdown]
# # Esercizio 1 - Basi
#
# Data un'equazione di secondo grado del tipo $ax^2 + bx + c = 0$ dove $a$, $b$ e $c$ sono coefficienti reali, le radici dell'equazione si trovano con la formula:
#
# $x = \frac{- b \pm \sqrt{b^2 - 4ac}}{2a}$
#
# Dati i coefficienti `a`, `b`, e `c`:
#
# 1. Scrivere un programma Python che calcola il valore di $x$ usando la formula, sopraindicata. E' importante notare che ci sono due possibili segni davanti alla radice quadrata, quindi due possibili valori di $x$.
#
#
# 2. Scrivere un programma Python che verifichi se è valida la condizione $b^2 - 4ac>0$ e stampi la condizione booleana dopo la domanda `Le radici dell'equazione sono reali e diverse?`
#
#
# 3. Scrivere un programma Python che verifichi se è valida la condizione $b^2 = 4ac$ e stampi la condizione booleana dopo la domanda `Le radici dell'equazione sono reali e identiche?`

# %%
a = 1
b = 10
c = -24

import math
#scrivi qui la soluzione

# %% [markdown]
# # Esercizio 2 - Stringhe

# %% [markdown]
# 1. Data una stringa nel formato `NOME_COGNOME_numtel`, scrivi un programma Python che:
# -  stampa separatamente il `NOME`, il `COGNOME`, e il `numtel`
# - verifica contemporaneamente che `NOME` e `COGNOME` siano stringhe letterali, e `numtel` sia un numero con una condizione booleana.
#
#
# 2. Dato un `intervallo` e una `parola`, scrivi un programma Python che stampa una NUOVA stringa con tutte le lettere di `parola` comprese nell'intervallo, in maiuscolo. Il carattere all’estremità sinistra dell’intervallo va INCLUSO, quello a destra va ESCLUSO.

# %%
stringa = "HERMIONE_GRANGER_0321402769"

#scrivi qui di seguito la soluzione.



intervallo = (3,8)
parola = "passeggiare"

#scrivi qui di seguito la soluzione. Il risultato dovrebbe essere: pasSEGGIare.

# %% [markdown]
# # Esercizio 3 - Liste

# %% [markdown]
# Hai a disposizione due liste: una contiene nomi di città, l’altra la rispettiva temperatura media invernale.
#
# ```python
# cities = ['Milano', 'Roma', 'Torino', 'Bologna', 'Firenze', 'Genova', 'Napoli', 'Palermo', 'Venezia', 'Verona']
# temps = [3.1, 8.2, 2.5, 4.0, 5.2, 6.1, 9.3, 12.4, 3.9, 2.8]
# ```
#
# 1. Crea una **nuova lista di tuple** del tipo `(città, temperatura)` **solo per le prime 5 città**.
# Stampa la nuova lista.
#
#
# 2. Calcola la **temperatura media** di tutte le città elencate e stampa il valore trovato.
#
#
# 3. Scrivi un programma Python che trova e stampa la **città più fredda** (cioè quella con la temperatura minima) nel formato:
# ```
# "La città più fredda è Torino con 2.5°C"
# ```

# %%
cities = ['Milano', 'Roma', 'Torino', 'Bologna', 'Firenze', 'Genova', 'Napoli', 'Palermo', 'Venezia', 'Verona']
temps = [3.1, 8.2, 2.5, 4.0, 5.2, 6.1, 9.3, 12.4, 3.9, 2.8]


#scrivi qui di seguito la soluzione

# %% [markdown]
# # Esercizio 4 - Dizionari

# %% [markdown]
# Vi viene dato un dizionario che contiene una lista di stati del mondo, a cui sono associati la rispettiva capitale e il continente a cui appartengono, come lista.
#
# ```python
# countries = {
#     'Italia': ['Roma', 'Europa'],
#     'Giappone': ['Tokyo', 'Asia'],
#     'Filippine': ['Manila', 'Asia'],
#     'India': ['Nuova Delhi', 'Asia'],
#     'Australia': ['Sydney', 'Oceania'],
#     'Kenya': ['Nairobi', 'Africa'],
#     'Svezia': ['Stoccolma', 'Europa'],
#     'Egitto': ['Cairo', 'Africa'],
#     'Canada': ['Ottawa', 'America'],
#
# }
# ```
#
# 1. C'è un errore! Qualcuno ha dimenticato che la capitale dell'Australia è Canberra, non Sydney. Modifica il dizionario in modo che alla chiave Australia sia associata la capitale corretta. Stampa il dizionario.
#
#
# 2. Stampa con `print` l'elenco degli stati presenti nel dizionario, in ordine alfabetico.
#
#
# 3. Scrivi un codice Python che crea un **nuovo** dizionario `conteggi` che associa ad ogni continente presente in `stati`, il numero di stati che vi appartengono (per esempio, Asia: 3).

# %%
countries = {
    'Italia': ['Roma', 'Europa'],
    'Giappone': ['Tokyo', 'Asia'],
    'Filippine': ['Manila', 'Asia'],
    'India': ['Nuova Delhi', 'Asia'],
    'Australia': ['Sydney', 'Oceania'],
    'Kenya': ['Nairobi', 'Africa'],
    'Svezia': ['Stoccolma', 'Europa'],
    'Egitto': ['Cairo', 'Africa'],
    'Canada': ['Ottawa', 'America'],
    
}

# %% [markdown]
# # Esercizio 5 - Controllo di flusso
#
# Vi viene dato un dizionario che contiene alcune città del mondo come chiavi. A ciascuna città è associato il **numero di abitanti (in milioni)**.
#
# ```python
# cities = {
#     'Tokyo': 37.4,
#     'Londra': 9.0,
#     'San Paolo': 22.0,
#     'Delhi': 32.0,
#     'New York': 18.8,
#     'Parigi': 11.3,
#     'Shanghai': 26.3,
#     'Il Cairo': 20.5,
#     'Sydney': 5.3,
# }
# ```
#
# 1. Scorri il dizionario e se trovi una città con popolazione **maggiore** di 20 milioni, stampane il nome.
#
#
# 2. Crea una lista, `pop_list`, contenente solo i valori di popolazione presi dal dizionario e ordinala in ordine **crescente**.
#
#
# 3. Data una popolazione totale, `tot_pop`, **conta** i primi `n` elementi della **lista ordinata** `pop_list` che **danno una somma minore di** `tot_pop`. Stampa **il numero**  `n` di elementi trovato.

# %%
cities = {
    'Tokyo': 37.4,
    'Londra': 9.0,
    'San Paolo': 22.0,
    'Delhi': 32.0,
    'New York': 18.8,
    'Parigi': 11.3,
    'Shanghai': 26.3,
    'Il Cairo': 20.5,
    'Sydney': 5.3,
}

tot_pop = 100.0

#scrivi qui la soluzione

# %% [markdown]
# # Esercizio 6 - Data analysis e funzioni

# %% [markdown]
# Vogliamo analizzare i dati contenuti nel file `AIRBNB_listings.csv`.
#
# Il file contiene un elenco di annunci di case disponibili su Airbnb a Stoccolma, con alcuni metadati.
#
# Usando la libreria `pandas`:
#
# 1. leggi il file .csv e crea un dataframe con il contenuto del file. Stampa le prime 5 righe del dataframe.
#
#
# 2. Ordina il dataframe in base alla colonna `price` e seleziona le 10 proprietà più costose della città. Salvale in un nuovo dataframe `top_price_df`.
#
#
# 3. Seleziona solo gli annunci che offrono l'intera casa (`Entire home/apt`) nella colonna `room_type`. Conta quanti sono in totale.
#
#
# 4. Disegna un grafico che mette in relazione la variabile `price` (prezzo) sull'asse y, con la variabile `number_of_reviews` sull'asse x. I punti nel grafico devono essere mostrati come **cerchi rossi**. Aggiungi delle etichette sugli assi, con i nomi delle variabili.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
