# %% [markdown]
# ## Esercitazione 2
# Aprile 2026

# %%
import math

# %% [markdown]
# # Esercizio 1
#
# Viene data una una stringa di nomi di città italiane, a cui è stata aggiunta la relativa popolazione, separati da virgole:
#
# ```python
# cities = "verona,255298|trento,118504|napoli,913704|palermo,630427|bari,316226|firenze,362613"
# ```
#
# Data la stringa `cities`:
#
# 1. Scrivere un programma Python che conta quante città sono presenti nella stringa e restituisce `True` se sono più di 5. Stampare il risultato con un `print`.
#
#
# 2. Scrivere un programma Python che produce una stringa con i nomi di città, separati da uno spazio. Il nome di ogni città deve avere l'iniziale maiuscola. Stampare il risultato con un `print`.
#
#
# 3. Calcolare la somma della popolazione di tutte le città e stampare il risultato con un  `print`.

# %%
cities = "verona,255298|trento,118504|napoli,913704|palermo,630427|bari,316226|firenze,362613"

#scrivi la soluzione
list_c = cities.split('|')
print(list_c)
print()
print('Nella stringa ci sono',len(list_c),'città')
cond=(len(list_c)>5)
print('Sono più di 5?', cond)
print()

stringa_c = list_c[0].split(',')[0].capitalize() + ' ' +list_c[1].split(',')[0].capitalize() + ' '+ list_c[2].split(',')[0].capitalize() + ' ' + list_c[3].split(',')[0].capitalize() + ' ' + list_c[4].split(',')[0].capitalize() + ' ' + list_c[5].split(',')[0].capitalize()
print(stringa_c)
print()

pop_tot = int(list_c[0].split(',')[1])+int(list_c[1].split(',')[1])+int(list_c[2].split(',')[1])+int(list_c[3].split(',')[1])+int(list_c[4].split(',')[1])+int(list_c[5].split(',')[1])
print('La popolazione totale è', pop_tot)
# Out:
# ['verona,255298', 'trento,118504', 'napoli,913704', 'palermo,630427', 'bari,316226', 'firenze,362613']
#
# Nella stringa ci sono 6 città
# Sono più di 5? True
#
# Verona Trento Napoli Palermo Bari Firenze
#
# La popolazione totale è 2596772

# %% [markdown]
# # Esercizio 2
#
# I voti di una sessione di laurea sono stati riportati in un'unica stringa che contiene i nomi dei candidati e il voto in cifre, separati da punto e virgola:
#
# ```python
# voti = "Anna 110;Beatrice 105;Carlo 110;Davide 107;Elena 109"
# ```
#
# Data la stringa `voti`:
#
# 1. Scrivere un programma Python che conta quanti voti sono presenti nella stringa e restituisce `True` se sono più di 4. Stampare il risultato con un `print`.
#
# 2. Scrivere un programma Python che produce una stringa con i soli voti di laurea, ma senza nomi, separati da una virgola. Stampare il risultato con un `print`.
#
# 2. Calcolare la media dei voti di laurea e stampare il risultato con un  `print`.

# %%
voti = "Anna 110;Beatrice 105;Carlo 110;Davide 107;Elena 109"

#scrivi qui di seguito la soluzione 
#conto il numero dei voti
list_v = voti.split(';')
print(list_v)
print()
print('Nella stringa ci sono',len(list_v),'voti')
cond=(len(list_v)>4)
print('Sono più di 4?', cond)
print()

#creo una lista con solo i voti laurea
vlist = [
         list_v[0].split()[1], list_v[1].split()[1],
         list_v[2].split()[1], list_v[3].split()[1],
         list_v[4].split()[1]
        ]
#print(vlist)
str_voti = ','.join(vlist)
print('La stringa completa di voti è:', str_voti)
print()

#calcolare la media dei voti
somma_voti = int(vlist[0])+int(vlist[1])+int(vlist[2])+int(vlist[3])+int(vlist[4])
media = somma_voti/len(vlist)
print('La media dei voti è:', media)
# Out:
# ['Anna 110', 'Beatrice 105', 'Carlo 110', 'Davide 107', 'Elena 109']
#
# Nella stringa ci sono 5 voti
# Sono più di 4? True
#
# La stringa completa di voti è: 110,105,110,107,109
#
# La media dei voti è: 108.2

# %% [markdown]
# # Esercizio 3
#
# Consideriamo tre stringhe diverse che contengono i versi delle prime 3 terzine dell'Inferno di Dante Alighieri.
#
# Purtroppo le stringhe non sono formattate correttamente. Tutti i caratteri di 'a capo' sono stati sostituiti con il carattere `|`.
#
# Scrivi un programma in Python che:
#
# 1. Sostituisce il simbolo `|` in ogni stringa con i simboli di a capo (new line) e salva ogni volta il risultato in una nuova stringa.
#
#
# 2. Unisce le tre stringhe modificate in un'unica stringa completa che rappresenta il testo formattato correttamente. Stampandola, dovrà apparire così:
#
# ```
# Nel mezzo del cammin di nostra vita
# mi ritrovai per una selva oscura,
# ché la diritta via era smarrita.
#
# Ahi quanto a dir qual era è cosa dura
# esta selva selvaggia e aspra e forte
# che nel pensier rinova la paura!
#
# Tant’è amara che poco è più morte;
# ma per trattar del ben ch’i’ vi trovai,
# dirò de l’altre cose ch’i’ v’ ho scorte.
#
# ```
#
# 3. Stampa la stringa completa con tutti i caratteri in MAIUSCOLO.
#
#
# 4. Stampa il numero totale di caratteri (la lunghezza) della stringa completa.

# %%
terzina1 = "Nel mezzo del cammin di nostra vita|mi ritrovai per una selva oscura,|ché la diritta via era smarrita.|"

terzina2 = "Ahi quanto a dir qual era è cosa dura|esta selva selvaggia e aspra e forte|che nel pensier rinova la paura!|"

terzina3 = "Tant’è amara che poco è più morte;|ma per trattar del ben ch’i’ vi trovai,|dirò de l’altre cose ch’i’ v’ ho scorte.|"

#sostituisco i caratteri in ogni stringa
ter1 = terzina1.replace('|','\n')
ter2 = terzina2.replace('|','\n')
ter3 = terzina3.replace('|','\n')

completa = ter1 + '\n'+ ter2 + '\n' + ter3
print(completa)

#stampo la stringa in maiuscolo
print(completa.upper())

print('Il numero totale di caratteri della stringa completa è:', len(completa))
# Out:
# Nel mezzo del cammin di nostra vita
# mi ritrovai per una selva oscura,
# ché la diritta via era smarrita.
#
# Ahi quanto a dir qual era è cosa dura
# esta selva selvaggia e aspra e forte
# che nel pensier rinova la paura!
#
# Tant’è amara che poco è più morte;
# ma per trattar del ben ch’i’ vi trovai,
# dirò de l’altre cose ch’i’ v’ ho scorte.
#
# NEL MEZZO DEL CAMMIN DI NOSTRA VITA
# MI RITROVAI PER UNA SELVA OSCURA,
# CHÉ LA DIRITTA VIA ERA SMARRITA.
#
# AHI QUANTO A DIR QUAL ERA È COSA DURA
# ESTA SELVA SELVAGGIA E ASPRA E FORTE
# CHE NEL PENSIER RINOVA LA PAURA!
#
# TANT’È AMARA CHE POCO È PIÙ MORTE;
# MA PER TRATTAR DEL BEN CH’I’ VI TROVAI,
# DIRÒ DE L’ALTRE COSE CH’I’ V’ HO SCORTE.
#
# Il numero totale di caratteri della stringa completa è: 329

# %% [markdown]
# # Esercizio 4
#
# Ti viene data una lista di interi contenente le età dei partecipanti ad un sondaggio:
#
# ```python
# ages = [23, 45, 18, 34, 55, 40, 30, 28, 60, 18, 19, 32, 41, 25]
# ```
# 1. Aggiungi i seguenti valori di età al fondo della lista: 44, 65. Stampa la lista.
#
#
# 2. Metti in ordine la lista, con i valori ordinati dal più piccolo al più grande. Stampa la lista ordinata.
#
#
# 3. Salva i primi 10 valori della lista ordinata in una nuova lista, `young_ages`, e stampala.
#
#
# 4. Calcola l'età media dei partecipanti, salvala nella variabile `mean_age` e stampala.

# %%
ages = [23, 45, 18, 34, 55, 40, 30, 28, 60, 18, 19, 32, 41, 25]

#aggiungo nuovi elementi alla lista
ages.append(44)
ages.append(65)
print('La lista aggiornata è:', ages)
print()
#ordino la lista 
ages.sort()
print('La lista ordinata è:', ages)
print()
#salvo i primi 10 valori in una nuova lista
young_ages=ages[:10]
print('I primi 10 valori della lista sono:', young_ages)
print()
#calcolo l'età media
mean_age=sum(ages)/len(ages)
print("L'età media è:", mean_age)
# Out:
# La lista aggiornata è: [23, 45, 18, 34, 55, 40, 30, 28, 60, 18, 19, 32, 41, 25, 44, 65]
#
# La lista ordinata è: [18, 18, 19, 23, 25, 28, 30, 32, 34, 40, 41, 44, 45, 55, 60, 65]
#
# I primi 10 valori della lista sono: [18, 18, 19, 23, 25, 28, 30, 32, 34, 40]
#
# L'età media è: 36.0625

# %% [markdown]
# # Esercizio 5
#
# Vi vengono date due liste contenenti le temperature registrate in due settimane, una di gennaio e una di febbraio 2024, a Trento:
#
# ```python
# temp_gennaio = [3, 6, -1, -2, 0, 3, 4]
# temp_febbraio = [2, 5, 3, 6, 7, 8, 4]
# ```
#
# 1. Scrivi un'espressione booleana che restituisce `True` solo le la temperatura massima di gennaio è **minore** della temperatura minima di febbraio.
#
#
# 2. Crea una singola lista `temp` che contiene tutte le temperature, di gennaio e febbraio. Stampa la lista con un `print`.
#
#
# 3. Calcola la temperatura media delle due settimane considerate. Stampala con un `print`.

# %%
temp_gennaio = [3, 6, -1, -2, 0, 3, 4]
temp_febbraio = [2, 5, 3, 6, 7, 8, 4]

#confronto le temperature massima di gennaio e minima di febbraio
cond=max(temp_gennaio)<min(temp_febbraio)
print('La temperatura max di gennaio è minore della min di febbraio?', cond)
print()

#creo una sola lista unica con tutte le temperature
temp = temp_gennaio + temp_febbraio
print('La lista completa è', temp)
print()

#calcolo la media di tutte le temperature
temp_avg=sum(temp)/len(temp)
print('La temperatura media nelle due settimane è:', temp_avg, '°C')
# Out:
# La temperatura max di gennaio è minore della min di febbraio? False
#
# La lista completa è [3, 6, -1, -2, 0, 3, 4, 2, 5, 3, 6, 7, 8, 4]
#
# La temperatura media nelle due settimane è: 3.4285714285714284 °C

# %% [markdown]
# # Esercizio 6

# %% [markdown]
# Un gruppo anonimo di hackers ha acquisito una lista di indirizzi email che vorrebbe usare per accedere al conto corrente degli ignari utenti della banca "MyBank". Per prima cosa è necessario verificare se ogni indirizzo email è composto in modo corretto.
#
# Gli hackers sanno che ogni indirizzo email di un utente dovrebbe essere così composto:
#
# `[solo lettere].[solo lettere]@mybank.com`
#
# Per esempio questo è un indirizzo email valido: `nome.cognome@mybank.com`.
#
# Scrivi del codice che stampa `True` se la stringa è un indirizzo email valido, `False` altrimenti.
#
# Prova le varie combinazioni scommentando la variabile `email`
#
# Il codice deve essere generico, valido per qualsiasi stringa.

# %%
email = 'nome.cognome@mybank.com' #True
#email = 'mio.nome@aol.com' #False
#email = 'mio.nome@mybank.it' #False


#controllo che l'indirizzo email finisca correttamente
email_split = email.split('@')
cond1 = email_split[1]=='mybank.com'
print('La mail finisce con mybank.com?', cond1)

#controllo la prima parte, separando la stringa sul simbolo .
lista2 = email_split[0].split('.')

#controllo condizione su nome
cond2 = lista2[0].isalpha()
print('Il nome è fatto di sole lettere?', cond2)

#controllo condizione su cognome
cond3 = lista2[1].isalpha()
print('Il cognome è fatto di sole lettere?', cond3)
print()

#metto insieme tutte e 3 le condizioni per verificare che l'indirizzo sia valido
print("L'indirizzo email è valido?")
print(cond1 and cond2 and cond3)
# Out:
# La mail finisce con mybank.com? True
# Il nome è fatto di sole lettere? True
# Il cognome è fatto di sole lettere? True
#
# L'indirizzo email è valido?
# True

# %% [markdown]
# In alternativa, il controllo sulla parte finale della stringa poteva essere fatto così:

# %%
email[-11:]=='@mybank.com'
# Out:
# True

# %% [markdown]
# oppure, in modo altrettanto corretto, così:

# %%
email.endswith('@mybank.com')
# Out:
# True
