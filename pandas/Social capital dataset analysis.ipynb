# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv('./social_capital_county.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3089 entries, 0 to 3088
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   county                        3089 non-null   int64
#  1   county_name                   3089 non-null   object
#  2   num_below_p50                 3087 non-null   float64
#  3   pop2018                       2983 non-null   float64
#  4   ec_county                     3018 non-null   float64
#  5   ec_se_county                  3018 non-null   float64
#  6   child_ec_county               2729 non-null   float64
#  7   child_ec_se_county            2729 non-null   float64
#  8   ec_grp_mem_county             3012 non-null   float64
#  9   ec_high_county                3018 non-null   float64
#  10  ec_high_se_county             3018 non-null   float64
#  11  child_high_ec_county          2729 non-null   float64
#  12  child_high_ec_se_county       2729 non-null   float64
#  13  ec_grp_mem_high_county        3012 non-null   float64
#  14  exposure_grp_mem_county       3012 non-null   float64
#  15  exposure_grp_mem_high_county  3012 non-null   float64
#  16  child_exposure_county         2729 non-null   float64
#  17  child_high_exposure_county    2729 non-null   float64
#  18  bias_grp_mem_county           3012 non-null   float64
#  19  bias_grp_mem_high_county      3012 non-null   float64
#  20  child_bias_county             2729 non-null   float64
#  21  child_high_bias_county        2729 non-null   float64
#  22  clustering_county             3089 non-null   float64
#  23  support_ratio_county          3089 non-null   float64
#  24  volunteering_rate_county      3089 non-null   float64
#  25  civic_organizations_county    3089 non-null   float64
# dtypes: float64(24), int64(1), object(1)
# memory usage: 627.6+ KB

# %%
df.head()
# Out:
#    county       county_name  num_below_p50   pop2018  ec_county  ec_se_county
# 0    1001  Autauga, Alabama      5922.3921   55200.0    0.72077       0.00831  \
# 1    1003  Baldwin, Alabama     15458.3960  208107.0    0.74313       0.00661
# 2    1005  Barbour, Alabama      4863.9736   25782.0    0.41366       0.00978
# 3    1007     Bibb, Alabama      3061.4934   22527.0    0.63152       0.01175
# 4    1009   Blount, Alabama      6740.9116   57645.0    0.72562       0.00985
#
#    child_ec_county  child_ec_se_county  ec_grp_mem_county  ec_high_county
# 0          1.11754             0.02467            0.77223         1.21372  \
# 1          0.83064             0.01629            0.76215         1.28302
# 2          0.58541             0.02707            0.35927         0.91897
# 3          0.72265             0.03027            0.68094         1.06378
# 4          0.76096             0.02466            0.79584         1.10569
#
#    ...  child_exposure_county  child_high_exposure_county
# 0  ...                1.14816                     1.19944  \
# 1  ...                0.84588                     1.00797
# 2  ...                0.63306                     0.71967
# 3  ...                0.71433                     0.72395
# 4  ...                0.74821                     0.79375
#
#    bias_grp_mem_county  bias_grp_mem_high_county  child_bias_county
# 0              0.05526                  -0.22748            0.02668  \
# 1              0.02950                  -0.21519            0.01802
# 2              0.13457                  -0.34086            0.07528
# 3              0.04108                  -0.27727           -0.01165
# 4              0.00217                  -0.24946           -0.01704
#
#    child_high_bias_county  clustering_county  support_ratio_county
# 0                -0.08229            0.10347               0.98275  \
# 1                -0.05241            0.09624               0.98684
# 2                -0.19714            0.14911               0.99911
# 3                -0.15993            0.14252               0.99716
# 4                -0.08745            0.11243               0.99069
#
#    volunteering_rate_county  civic_organizations_county
# 0                   0.04355                     0.01518
# 1                   0.06117                     0.01526
# 2                   0.02093                     0.01474
# 3                   0.05294                     0.01439
# 4                   0.05704                     0.01724
#
# [5 rows x 26 columns]

# %%
df_alabama = df[df['county_name'].str.contains('Alabama')]

# %%
df_alabama
# Out:
#     county          county_name  num_below_p50   pop2018  ec_county
# 0     1001     Autauga, Alabama      5922.3921   55200.0    0.72077  \
# 1     1003     Baldwin, Alabama     15458.3960  208107.0    0.74313
# 2     1005     Barbour, Alabama      4863.9736   25782.0    0.41366
# 3     1007        Bibb, Alabama      3061.4934   22527.0    0.63152
# 4     1009      Blount, Alabama      6740.9116   57645.0    0.72562
# ..     ...                  ...            ...       ...        ...
# 62    1125  Tuscaloosa, Alabama     19993.4240  206213.0    0.64775
# 63    1127      Walker, Alabama      9327.2041   64493.0    0.64082
# 64    1129  Washington, Alabama      2959.3025   16643.0    0.70414
# 65    1131      Wilcox, Alabama      3067.6301   10809.0    0.42162
# 66    1133     Winston, Alabama      3878.0425   23875.0    0.59921
#
#     ec_se_county  child_ec_county  child_ec_se_county  ec_grp_mem_county
# 0        0.00831          1.11754             0.02467            0.77223  \
# 1        0.00661          0.83064             0.01629            0.76215
# 2        0.00978          0.58541             0.02707            0.35927
# 3        0.01175          0.72265             0.03027            0.68094
# 4        0.00985          0.76096             0.02466            0.79584
# ..           ...              ...                 ...                ...
# 62       0.00637          0.82072             0.01731            0.69414
# 63       0.00915          0.62895             0.02588            0.66590
# 64       0.01217          0.79620             0.03562            0.76392
# 65       0.01182          0.34766             0.02934            0.38919
# 66       0.01115          0.56680             0.03017            0.57190
#
#     ec_high_county  ...  child_exposure_county  child_high_exposure_county
# 0          1.21372  ...                1.14816                     1.19944  \
# 1          1.28302  ...                0.84588                     1.00797
# 2          0.91897  ...                0.63306                     0.71967
# 3          1.06378  ...                0.71433                     0.72395
# 4          1.10569  ...                0.74821                     0.79375
# ..             ...  ...                    ...                         ...
# 62         1.23939  ...                0.84589                     0.96254
# 63         1.06065  ...                0.63792                     0.73405
# 64         1.05941  ...                0.74944                     0.77577
# 65         0.96622  ...                0.35417                     0.58654
# 66         0.94876  ...                0.55864                     0.56385
#
#     bias_grp_mem_county  bias_grp_mem_high_county  child_bias_county
# 0               0.05526                  -0.22748            0.02668  \
# 1               0.02950                  -0.21519            0.01802
# 2               0.13457                  -0.34086            0.07528
# 3               0.04108                  -0.27727           -0.01165
# 4               0.00217                  -0.24946           -0.01704
# ..                  ...                       ...                ...
# 62              0.18635                  -0.18066            0.02976
# 63              0.05898                  -0.25173            0.01407
# 64             -0.00543                  -0.23278           -0.06239
# 65              0.07042                  -0.28760            0.01837
# 66              0.02396                  -0.31681           -0.01459
#
#     child_high_bias_county  clustering_county  support_ratio_county
# 0                 -0.08229            0.10347               0.98275  \
# 1                 -0.05241            0.09624               0.98684
# 2                 -0.19714            0.14911               0.99911
# 3                 -0.15993            0.14252               0.99716
# 4                 -0.08745            0.11243               0.99069
# ..                     ...                ...                   ...
# 62                -0.11356            0.11285               0.99622
# 63                -0.08380            0.11568               0.99795
# 64                -0.07522            0.14909               0.99854
# 65                -0.04717            0.19053               0.99989
# 66                -0.14970            0.12928               0.99744
#
#     volunteering_rate_county  civic_organizations_county
# 0                    0.04355                     0.01518
# 1                    0.06117                     0.01526
# 2                    0.02093                     0.01474
# 3                    0.05294                     0.01439
# 4                    0.05704                     0.01724
# ..                       ...                         ...
# 62                   0.04510                     0.01334
# 63                   0.04503                     0.01458
# 64                   0.03182                     0.01032
# 65                   0.01901                     0.01398
# 66                   0.03503                     0.01305
#
# [67 rows x 26 columns]

# %%
df_ny = df[df['county_name'].str.contains('New York')]

# %%
df_ny
# Out:
#       county            county_name  num_below_p50    pop2018  ec_county
# 1806   36001       Albany, New York     19730.4530   307426.0    0.87391  \
# 1807   36003     Allegany, New York      6156.7988    47025.0    0.77830
# 1808   36005        Bronx, New York    306567.2200  1437872.0    0.68067
# 1809   36007       Broome, New York     17773.2990   194402.0    0.81245
# 1810   36009  Cattaraugus, New York     10743.7870    77686.0    0.75653
# ...      ...                    ...            ...        ...        ...
# 1863   36115   Washington, New York      7010.4185    61828.0    0.83695
# 1864   36117        Wayne, New York      9204.1865    90856.0    0.84524
# 1865   36119  Westchester, New York     72428.8670   968815.0    0.81660
# 1866   36121      Wyoming, New York      4121.3638    40565.0    0.91835
# 1867   36123        Yates, New York      3377.3796    25009.0    0.83705
#
#       ec_se_county  child_ec_county  child_ec_se_county  ec_grp_mem_county
# 1806       0.00696          1.07797             0.01660            0.93122  \
# 1807       0.01046          0.72988             0.02813            0.77641
# 1808       0.00582          0.64668             0.02103            0.71643
# 1809       0.00765          0.95977             0.01779            0.83284
# 1810       0.00883          0.79904             0.02362            0.74164
# ...            ...              ...                 ...                ...
# 1863       0.00946          0.90398             0.02653            0.86633
# 1864       0.00851          0.88739             0.02070            0.88855
# 1865       0.00707          1.12902             0.01667            0.83242
# 1866       0.01080          0.83573             0.03192            0.98200
# 1867       0.01365          0.86294             0.03091            0.84815
#
#       ec_high_county  ...  child_exposure_county  child_high_exposure_county
# 1806         1.46298  ...                1.10912                     1.29037  \
# 1807         1.17528  ...                0.69635                     0.76427
# 1808         1.05966  ...                0.62279                     0.93848
# 1809         1.32753  ...                0.96992                     1.04441
# 1810         1.17481  ...                0.79991                     0.83291
# ...              ...  ...                    ...                         ...
# 1863         1.24874  ...                0.89516                     0.92800
# 1864         1.28471  ...                0.87898                     0.92534
# 1865         1.54990  ...                1.17624                     1.53775
# 1866         1.24324  ...                0.83491                     0.85764
# 1867         1.24484  ...                0.86367                     0.89063
#
#       bias_grp_mem_county  bias_grp_mem_high_county  child_bias_county
# 1806              0.09544                  -0.10858            0.02809  \
# 1807              0.05611                  -0.16242           -0.04814
# 1808              0.07198                  -0.05801           -0.03836
# 1809              0.11081                  -0.17814            0.01046
# 1810              0.07970                  -0.18230            0.00109
# ...                   ...                       ...                ...
# 1863              0.10965                  -0.14908           -0.00986
# 1864              0.07851                  -0.14922           -0.00957
# 1865              0.15073                  -0.07636            0.04014
# 1866              0.03437                  -0.14278           -0.00098
# 1867              0.06515                  -0.15875            0.00085
#
#       child_high_bias_county  clustering_county  support_ratio_county
# 1806                -0.03760            0.09890               0.97807  \
# 1807                -0.07987            0.11585               0.99304
# 1808                -0.02937            0.07162               0.93306
# 1809                -0.08075            0.10276               0.99236
# 1810                -0.10368            0.11800               0.99380
# ...                      ...                ...                   ...
# 1863                -0.06501            0.11018               0.98862
# 1864                -0.06865            0.10943               0.98842
# 1865                -0.03532            0.09368               0.96771
# 1866                -0.06918            0.12014               0.99257
# 1867                -0.07964            0.12251               0.99614
#
#       volunteering_rate_county  civic_organizations_county
# 1806                   0.08142                     0.02288
# 1807                   0.07390                     0.02430
# 1808                   0.02304                     0.00649
# 1809                   0.07719                     0.01678
# 1810                   0.07353                     0.01886
# ...                        ...                         ...
# 1863                   0.12213                     0.01706
# 1864                   0.09101                     0.01574
# 1865                   0.05070                     0.01653
# 1866                   0.06816                     0.02165
# 1867                   0.08529                     0.03253
#
# [62 rows x 26 columns]

# %%
alabama_ec_mean = df_alabama['ec_county'].mean()
ny_ec_mean = df_ny['ec_county'].mean()

# %%
alabama_ec_mean
# Out:
# 0.5954700006060606

# %%
ny_ec_mean
# Out:
# 0.8398341932258064

# %%
# Figura

# %%
plt.figure(figsize=(8,4))
plt.plot( df['ec_county'], df['volunteering_rate_county'], 'o', markersize=2 )

plt.xlabel('EC index')
plt.ylabel('Volunteering rate')
# Out:
# Text(0, 0.5, 'Volunteering rate')

# %%
df['ec_county'].mean()
# Out:
# 0.8144641210868125

# %%
df['volunteering_rate_county'].mean()
# Out:
# 0.07806774976413079

# %%
df[ df['volunteering_rate_county']>0.23 ]
# Out:
#       county          county_name  num_below_p50  pop2018  ec_county
# 885    20005     Atchison, Kansas     2014.43800  16363.0    0.91581  \
# 894    20023     Cheyenne, Kansas      535.92914   2677.0    0.99049
# 918    20071      Greeley, Kansas      211.96527   1200.0        NaN
# 1259   26067      Ionia, Michigan     5954.51950  64176.0    0.84526
# 1291   26131  Ontonagon, Michigan      715.34192   5968.0    0.89140
# 2575   48155         Foard, Texas      325.28586      NaN        NaN
# 2614   48235         Irion, Texas      219.45839      NaN        NaN
# 2663   48341         Moore, Texas     3741.33450  21801.0    0.62012
# 2713   48447  Throckmorton, Texas      366.39597      NaN        NaN
# 3079   56027    Niobrara, Wyoming      268.87433      NaN    0.97450
#
#       ec_se_county  child_ec_county  child_ec_se_county  ec_grp_mem_county
# 885        0.01546          0.85604             0.03860            0.88139  \
# 894        0.03573              NaN                 NaN            1.14147
# 918            NaN              NaN                 NaN                NaN
# 1259       0.01004          0.83211             0.02246            0.90689
# 1291       0.02234              NaN                 NaN            0.89052
# 2575           NaN              NaN                 NaN                NaN
# 2614           NaN              NaN                 NaN                NaN
# 2663       0.01345          0.83199             0.03497            0.77468
# 2713           NaN              NaN                 NaN                NaN
# 3079       0.02936              NaN                 NaN            0.89632
#
#       ec_high_county  ...  child_exposure_county  child_high_exposure_county
# 885          1.38866  ...                0.86276                     0.92255  \
# 894          1.38989  ...                    NaN                         NaN
# 918              NaN  ...                    NaN                         NaN
# 1259         1.28009  ...                0.82683                     0.85643
# 1291         1.22059  ...                    NaN                         NaN
# 2575             NaN  ...                    NaN                         NaN
# 2614             NaN  ...                    NaN                         NaN
# 2663         1.09637  ...                0.89639                     0.93501
# 2713             NaN  ...                    NaN                         NaN
# 3079         1.32611  ...                    NaN                         NaN
#
#       bias_grp_mem_county  bias_grp_mem_high_county  child_bias_county
# 885               0.05827                  -0.21178            0.00778  \
# 894               0.00305                  -0.14576                NaN
# 918                   NaN                       NaN                NaN
# 1259              0.07449                  -0.16478           -0.00638
# 1291             -0.01397                  -0.15386                NaN
# 2575                  NaN                       NaN                NaN
# 2614                  NaN                       NaN                NaN
# 2663              0.13399                  -0.19197            0.07184
# 2713                  NaN                       NaN                NaN
# 3079              0.09905                  -0.12471                NaN
#
#       child_high_bias_county  clustering_county  support_ratio_county
# 885                 -0.07530           0.125880              0.996440  \
# 894                      NaN           0.114460              0.996320
# 918                      NaN           0.121041              0.997069
# 1259                -0.07602           0.114260              0.986490
# 1291                     NaN           0.150630              0.996390
# 2575                     NaN           0.131277              0.997529
# 2614                     NaN           0.097053              0.989378
# 2663                -0.11111           0.112190              0.997360
# 2713                     NaN           0.105239              0.996970
# 3079                     NaN           0.112420              0.996390
#
#       volunteering_rate_county  civic_organizations_county
# 885                   0.235080                    0.021140
# 894                   0.273580                    0.043560
# 918                   0.287265                    0.055153
# 1259                  0.246370                    0.014950
# 1291                  0.243660                    0.038100
# 2575                  0.308736                    0.045566
# 2614                  0.239626                    0.024603
# 2663                  0.252610                    0.011670
# 2713                  0.244292                    0.028432
# 3079                  0.271360                    0.036680
#
# [10 rows x 26 columns]
